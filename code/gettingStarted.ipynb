% %% [markdown]
% # <span style="color:rgb(213,80,0)">Getting Started with Mass\-Spring\-Damper Toolbox</span>
%
% ## Description
%
% This is a simple demo toolbox with some utilities that can support Mass\-Spring\-Damper systems.
%
% ## Features
%
% Provide an overview of the features that your toolbox integrates with MATLAB here.
%
% ## Examples

% %%
[result, time] = simulateSystem(springMassDamperDesign);
plot(time, result);
title("Step Response of the System")
% Out:
% <center><img src="data:image/png;base64,..." width="495" alt="figure_0.png"></center>
